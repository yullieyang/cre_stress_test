# %% [markdown]
# ##Q1

# %%
def max_difference(x):
    for number in x:
        diff = (number[i] -number[i-1] for i in range(1, len(number)))     
    print( max(diff), "number[i] - number[i-1]")

# %% [markdown]
# ##Q2

# %%
SSN = input("Enter your SSN in 9 digit format with dahses ")

# %%
if "-" in SSN:
    print("SSN is valid")
else:
    print("False")
# Out:
# False

# %% [markdown]
# ##q3

# %%
import pandas as pd

# %%
df = pd.read_csv('loans.csv')

# %%
print(df.head())
# Out:
#    PropertyTypeID OriginationDate  LoanAmount   LTV  Unnamed: 4  Unnamed: 5  \
# 0               1        3/1/2025    120000.0  0.44         NaN         NaN
# 1               1       11/1/2024    190000.0  0.67         NaN         NaN
# 2               1        1/1/2025         NaN  0.42         NaN         NaN
# 3               1        7/1/2024    230000.0  0.71         NaN         NaN
# 4               2        3/1/2025    400000.0  0.81         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Unnamed: 4         17
# Unnamed: 5         17
# Unnamed: 6         17
# Unnamed: 7         17
# LoanAmount          2
# PropertyTypeID      0
# OriginationDate     0
# LTV                 0
# dtype: int64

# %%
#calculate the totla loan amount by year and month of the origniation date

# %%
df.head()
# Out:
#    PropertyTypeID OriginationDate  LoanAmount   LTV  Unnamed: 4  Unnamed: 5  \
# 0               1        3/1/2025    120000.0  0.44         NaN         NaN
# 1               1       11/1/2024    190000.0  0.67         NaN         NaN
# 2               1        1/1/2025         NaN  0.42         NaN         NaN
# 3               1        7/1/2024    230000.0  0.71         NaN         NaN
# 4               2        3/1/2025    400000.0  0.81         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
date= pd.to_datetime(df['OriginationDate'], format='%m/%d/%Y')
